# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_context("poster")
sns.set(rc={"figure.figsize": (10.,8.)})
sns.set_style("whitegrid")

# %%
train=pd.read_csv('../data/trainclean.csv')

# %%
train.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  ID    Gene             Variation VariationType  \
# 0           0             0   0  FAM58A  Truncating Mutations       unknown
# 1           1             1   1     CBL                 W802*  Substitution
# 2           2             2   2     CBL                 Q249E  Substitution
# 3           3             3   3     CBL                 N454D  Substitution
# 4           4             4   4     CBL                 L399V  Substitution
#
#      Effect  Class                                               TEXT  \
# 0  nonsense      1  cyclin dependent kinases cdks regulate variety...
# 1  nonsense      2  abstract background non small cell lung cancer...
# 2  missense      2  abstract background non small cell lung cancer...
# 3  missense      3  recent evidence demonstrated acquired uniparen...
# 4  missense      4  oncogenic mutations monomeric casitas b lineag...
#
#          GeneType Chromosome                   Role      TumourType
# 0         Unknown    unknown                Unknown         Unknown
# 1  protein-coding         11  oncogene, TSG, fusion  AML, JMML, MDS
# 2  protein-coding         11  oncogene, TSG, fusion  AML, JMML, MDS
# 3  protein-coding         11  oncogene, TSG, fusion  AML, JMML, MDS
# 4  protein-coding         11  oncogene, TSG, fusion  AML, JMML, MDS

# %%
train.drop(columns=['TEXT'], inplace= True)

# %%
train.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  ID    Gene             Variation VariationType  \
# 0           0             0   0  FAM58A  Truncating Mutations       unknown
# 1           1             1   1     CBL                 W802*  Substitution
# 2           2             2   2     CBL                 Q249E  Substitution
# 3           3             3   3     CBL                 N454D  Substitution
# 4           4             4   4     CBL                 L399V  Substitution
#
#      Effect  Class        GeneType Chromosome                   Role  \
# 0  nonsense      1         Unknown    unknown                Unknown
# 1  nonsense      2  protein-coding         11  oncogene, TSG, fusion
# 2  missense      2  protein-coding         11  oncogene, TSG, fusion
# 3  missense      3  protein-coding         11  oncogene, TSG, fusion
# 4  missense      4  protein-coding         11  oncogene, TSG, fusion
#
#        TumourType
# 0         Unknown
# 1  AML, JMML, MDS
# 2  AML, JMML, MDS
# 3  AML, JMML, MDS
# 4  AML, JMML, MDS

# %%
train.drop(columns=['Unnamed: 0', 'Unnamed: 0.1'], inplace= True)

# %%
train.head()
# Out:
#    ID    Gene             Variation VariationType    Effect  Class  \
# 0   0  FAM58A  Truncating Mutations       unknown  nonsense      1
# 1   1     CBL                 W802*  Substitution  nonsense      2
# 2   2     CBL                 Q249E  Substitution  missense      2
# 3   3     CBL                 N454D  Substitution  missense      3
# 4   4     CBL                 L399V  Substitution  missense      4
#
#          GeneType Chromosome                   Role      TumourType
# 0         Unknown    unknown                Unknown         Unknown
# 1  protein-coding         11  oncogene, TSG, fusion  AML, JMML, MDS
# 2  protein-coding         11  oncogene, TSG, fusion  AML, JMML, MDS
# 3  protein-coding         11  oncogene, TSG, fusion  AML, JMML, MDS
# 4  protein-coding         11  oncogene, TSG, fusion  AML, JMML, MDS

# %%
train.to_csv('../data/train_no_text.csv')

# %%
enseñar prediccion de resultado
